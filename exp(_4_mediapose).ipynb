# %% [markdown]
# <a href="https://colab.research.google.com/github/balamurugan-k006/computer-vision-/blob/main/exp(_4_mediapose).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import mediapipe as mp
from google.colab.patches import cv2_imshow

# Initialize MediaPipe
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

def estimate_pose_from_image(image_path):

    # Read image
    image = cv2.imread(image_path)

    if image is None:
        print("Image not found!")
        return

    # Convert to RGB
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Create Pose object
    with mp_pose.Pose(static_image_mode=True,
                      min_detection_confidence=0.5) as pose:

        results = pose.process(image_rgb)

        # Draw landmarks
        if results.pose_landmarks:
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS
            )

    # Show image in Colab
    cv2_imshow(image)

# Upload your image first in Colab
estimate_pose_from_image("/content/mediapose.png")  # Change filename
