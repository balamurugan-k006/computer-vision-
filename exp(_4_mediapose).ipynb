# %% [markdown]
# <a href="https://colab.research.google.com/github/balamurugan-k006/computer-vision-/blob/main/exp(_4_mediapose).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import mediapipe as mp
from IPython.display import HTML
from base64 import b64encode
import os

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

def estimate_pose_colab(video_path, output_path="pose_output.mp4", width=640, height=480):

    if not os.path.exists(video_path):
        print("❌ Video file not found!")
        return

    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print("❌ Error opening video file")
        return

    fps = cap.get(cv2.CAP_PROP_FPS)
    if fps == 0:
        fps = 30  # default fallback fps

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, int(fps), (width, height))

    with mp_pose.Pose(min_detection_confidence=0.5,
                      min_tracking_confidence=0.5) as pose:

        while True:
            ret, frame = cap.read()
            if not ret:
                break

            frame = cv2.resize(frame, (width, height))
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

            results = pose.process(frame_rgb)

            if results.pose_landmarks:
                mp_drawing.draw_landmarks(
                    frame,
                    results.pose_landmarks,
                    mp_pose.POSE_CONNECTIONS
                )

            out.write(frame)

    cap.release()
    out.release()

    print("✅ Processing Finished!")

    # Display video in Colab
    mp4 = open(output_path,'rb').read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
    return HTML(f'<video width=600 controls><source src="{data_url}" type="video/mp4"></video>')


# Run pose estimation
estimate_pose_colab("/content/Bala media pose video (1).mp4")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_294/3711667451.py in <cell line: 0>()
#       1 import cv2
# ----> 2 import mediapipe as mp
#       3 from IPython.display import HTML
#       4 from base64 import b64encode
#       5 import os
#
# ModuleNotFoundError: No module named 'mediapipe'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install mediapipe opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 59.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 12.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
# ...

# %%
# !pip install mediapipe

# %%
import cv2
import mediapipe as mp

# %%
import cv2
import mediapipe as mp
from IPython.display import HTML
from base64 import b64encode
import os

def estimate_pose_colab(video_path, output_path="pose_output.mp4", width=640, height=480):

    # Check if file exists
    if not os.path.exists(video_path):
        print("❌ Video file not found!")
        return

    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print("❌ Error opening video file")
        return

    # Get FPS safely
    fps = cap.get(cv2.CAP_PROP_FPS)
    if fps == 0:
        fps = 30

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, int(fps), (width, height))

    mp_pose = mp.solutions.pose
    mp_drawing = mp.solutions.drawing_utils

    with mp_pose.Pose(min_detection_confidence=0.5,
                      min_tracking_confidence=0.5) as pose:

        while True:
            ret, frame = cap.read()
            if not ret:
                break

            frame = cv2.resize(frame, (width, height))
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

            results = pose.process(frame_rgb)

            if results.pose_landmarks:
                mp_drawing.draw_landmarks(
                    frame,
                    results.pose_landmarks,
                    mp_pose.POSE_CONNECTIONS
                )

            out.write(frame)

    cap.release()
    out.release()

    print("✅ Processing Finished!")

    # Display video in Colab
    mp4 = open(output_path,'rb').read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
    return HTML(f'''
    <video width=600 controls>
        <source src="{data_url}" type="video/mp4">
    </video>
    ''')

# 🔹 Run the function (Change path if needed)
estimate_pose_colab("/content/Bala media pose video.mp4")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1347/1079707070.py in <cell line: 0>()
#      66
#      67 # 🔹 Run the function (Change path if needed)
# ---> 68 estimate_pose_colab("/content/Bala media pose video.mp4")
#
# /tmp/ipykernel_1347/1079707070.py in estimate_pose_colab(video_path, output_path, width, height)
#      26     out = cv2.VideoWriter(output_path, fourcc, int(fps), (width, height))
#      27
# ---> 28     mp_pose = mp.solutions.pose
#      29     mp_drawing = mp.solutions.drawing_utils
#      30
#
# AttributeError: module 'mediapipe' has no attribute 'solutions'

# %%
import cv2
import mediapipe as mp
import os
from IPython.display import HTML
from base64 import b64encode

def estimate_pose_colab(video_path, output_path="pose_output.mp4", width=640, height=480):

    if not os.path.exists(video_path):
        print("❌ Video file not found!")
        return

    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print("❌ Cannot open video")
        return

    fps = cap.get(cv2.CAP_PROP_FPS)
    if fps == 0:
        fps = 30

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, int(fps), (width, height))

    mp_pose = mp.solutions.pose
    mp_drawing = mp.solutions.drawing_utils

    with mp_pose.Pose(static_image_mode=False,
                      min_detection_confidence=0.5,
                      min_tracking_confidence=0.5) as pose:

        while True:
            ret, frame = cap.read()
            if not ret:
                break

            frame = cv2.resize(frame, (width, height))
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

            results = pose.process(frame_rgb)

            if results.pose_landmarks:
                mp_drawing.draw_landmarks(
                    frame,
                    results.pose_landmarks,
                    mp_pose.POSE_CONNECTIONS
                )

            out.write(frame)

    cap.release()
    out.release()

    print("✅ Processing Finished!")

    # Display video
    mp4 = open(output_path,'rb').read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
    return HTML(f'<video width=600 controls><source src="{data_url}" type="video/mp4"></video>')


# Run
estimate_pose_colab("/content/Bala media pose video.mp4")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1347/479313888.py in <cell line: 0>()
#      62
#      63 # Run
# ---> 64 estimate_pose_colab("/content/Bala media pose video.mp4")
#
# /tmp/ipykernel_1347/479313888.py in estimate_pose_colab(video_path, output_path, width, height)
#      24     out = cv2.VideoWriter(output_path, fourcc, int(fps), (width, height))
#      25
# ---> 26     mp_pose = mp.solutions.pose
#      27     mp_drawing = mp.solutions.drawing_utils
#      28
#
# AttributeError: module 'mediapipe' has no attribute 'solutions'

# %%
# !pip install mediapipe opencv-python
